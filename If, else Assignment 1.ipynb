# %%
units=int(input("Enter number of Units"))
Bill=0

if units<=100:
    Bill=0

elif units<=200:
    bill=(units-100)*5

else:
    bill=(100*5)+(units-200)*10

print("Your electricity bill is=",bill)
# Out:
# Enter number of Units 525
# Your electricity bill is= 3750

# %%
percentage=float(input("Enter your percentage"))
Grade="char"
if percentage>90:
    Grade="A"

elif percentage>80:
    Grade="B"
elif percentage>=60:
    Grade="C"
else:
    Grade="D"
print("According to given Percentage your Grade=",Grade)
# Out:
# Enter your percentage 59
# According to given Percentage your Grade= D

# %%
person1=int(input("Enter your Age"))
person2=int(input("Enter your Age"))
person3=int(input("Enter your Age"))
person4=int(input("Enter your Age"))

if person1 <= person2 and person3 and person4:
    print("person1 is youngest")

elif person2 <= person1 and person3 and person4:
    print("person2 is youngest")

elif person3 <= person2 and person1 and person4:
    print("person3 is youngest")

else:
    print("person4 is youngest")
# Out:
# Enter your Age 55
# Enter your Age 55
# Enter your Age 55
# Enter your Age 55
# person1 is youngest

# %%
Salary=int(input("Enter your salary"))
Service=int(input("Enter your years of Service"))
bonus = 0
if Service>=10:
    bonus=(10/100)*Salary
elif Service>=6:
    bonus=(8/100)*Salary
else:
    bonus=(5/100)*Salary
print("Congratulations your Bonus is",bonus)
print("Your Total Salary with Bonus For the month=",bonus+Salary)
# Out:
# Enter your salary 100000
# Enter your years of Service 12
# Congratulations your Bonus is 10000.0
# Your Total Salary with Bonus For the month= 110000.0

# %%
Number1=int(input("Enter the First Number"))
Number2=int(input("Enter the Second Number"))
Number3=int(input("Enter the Third Number"))

if (Number1>=Number2 and Number1<= Number3) or (Number1<=Number2 and Number1>= Number3):
    print("Number1 is Second Largest")
elif (Number1>=Number2 and Number1<= Number3) or (Number1<=Number2 and Number1>= Number3):
    print("Number2 is Second Largest")
else:
    print("Number3 is Second Largest")
# Out:
# Enter the First Number 1
# Enter the Second Number 2
# Enter the Third Number 3
# Number3 is Second Largest

# %%
Mtp=float(input("Enter the Marked Price"))
finalprice=0
if Mtp>10000:
    finalprice=Mtp-((20/100)*Mtp)
elif Mtp>7000:
    finalprice=Mtp-((15/100)*Mtp)
else:
    finalprice=Mtp-((10/100)*Mtp)
print("The Net Amount=",finalprice )
# Out:
# Enter the Marked Price 100
# The Net Amount= 90.0

# %%
English=int(input("Enter your Marks of English"))
Maths=int(input("Enter your Marks of Maths"))
Science=int(input("Enter your Marks of Science"))
Social_Studies=int(input("Enter your Marks of Social_Studies"))

if (English>80 and Social_Studies>80):
    print("You have been alloted Humanities Stream")
elif (English>80 and Maths,Science>50):
    print("You have been alloted Commerce Stream")
elif (English,Maths,Science,Social_Studies>80):
    print("You have been alloted Science Stream")
else:
    print("You Failed")
# Out:
# Enter your Marks of English 20
# Enter your Marks of Maths 50
# Enter your Marks of Science 80
# Enter your Marks of Social_Studies 80
# You have been alloted Commerce Stream

# %%
Number=int(input("Enter the Number"))

if (Number%5 == 0):
    print("Hello")
else:
    print("Bye")
# Out:
# Enter the Number 10
# Hello

# %%
Number=int(input("Enter the Number"))

if len(str(Number))==3:
    print("Yes")
else:
    print("No")
# Out:
# Enter the Number 16515
# No
